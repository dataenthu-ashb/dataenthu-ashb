# %% [markdown]
# # Assignment 5
#
# In this assignment we are going to progam a game. Namely snakes and ladders. In snakes and ladders you have a board like you can see in the picture, the snakes bring you to a lower tile and a ladder brings you up higher. The goal of the game is to be the first to reach the last tile.
# ![Marian-de-Ridder-slangen-en-ladders-rekenen-groep-3-4-tot-20-1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# To program this game we need to create classes. Namely a piece, a tile, a board and a game.

# %% [markdown]
# ## Exercise 1 - Piece
#
# A piece has 3 attributes, namely a player (the name of the player), a colour and a position on the board.
#
# a) Make a 'def __init__(self, name, colour)' and set the initial position to 1 (the first tile).
#
# b) To use a piece we also need to be able to update the position of the piece. Write a method that updates the position as mentioned in below code.

# %%
#make the class

  #a)
  def __init__(self, name, colour):


  #b)
  def move(self, new_position):

# %% [markdown]
# ## Exercise 2 - Tile
#
# Now that we have the pieces it is time to make a tile on the board. A tile has a number and a boolean variables and a next tile number. The boolean variable is to indicate if the tile is a normal tile or a tile with a snake or a ladder.
# This defferentiation is important cause in case tile has ladder or snake you need to move up or down accordingly and in case of normal tile there will be no change.

# %%
#make the class
  def __init__(self, number, normal, next_number):
  #your code

# %% [markdown]
# ## Exercise 3 - Board
# The board is essentially made up of multiple tiles. So to build the board we have to give the max number of tiles and a list that contains the tile numbers and the next tile numbers of snakes and ladders. For the last tile in the board you can either choose the value next_number as max_number + 1 or max_number. You then have to make all the tiles in the board.
#
# Example:
# So if the board is 4 tiles long and it has a snack at 3 back to 1. Then max_number = 4 and list_of_tiles = {3: 1}

# %%
#make the class
  def __init__(self, max_number, dic_of_tiles):
    #your code

# %% [markdown]
# ## Exercise 4 - Game
#
# Now that we have the board, tiles and the pieces we can start to program the game. To do this we make a constructor for a game that takes in a list of players and a board.
# a) Make the constructor for the game.

# %% [markdown]
# Then we have two more methods to make namely a turn(Piece) and play().
#
# b) First we make a turn. When it is a players turn they role the dice with numbers from 1 to 6 and they walk the number of steps that equal the number of eyes on the dice. So a 3 in the dice means 3 steps. If they then end on a ladder or snake they immediately travel to the higher or lower respectively immediately.
# Write the method turn() that does this. You can use the code below to generate a random number to simulate the dice. This question is the most difficult in the assignment so don't worry if it takes a while.

# %% [markdown]
# c) Now that we have the program for a turn it is time to make the method play(), which will play the whole game from start to finish. This means that the players take turn(s) until one of the players is on a number higher than max_number from board.

# %%
import random

class Game:
  #a)
  def __init__(self, list_pieces, board):

  #b)
  def turn(self, piece):

  #c)
  def play(self):

# %% [markdown]
# ## Exercise 5 - It's time to play!
# Initialize objects of the classes that you created with proper arguments and begin the game!

# %%
#your code

# %%
##
